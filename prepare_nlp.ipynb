# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd
from time import strftime

import acquire

# %%
# use acquire function to get an article
string = acquire.get_blog_articles('https://codeup.com/codeup-news/vet-tec-funding-dallas/')
type(string)
# Out:
# dict

# %%
# pull only the string
string = string['content']

string
# Out:
# 'We are so happy to announce that VET TEC benefits are now available to be used at our campus located in Dallas, TX! Our next Dallas start date for our web development program is January 31st, 2022!\nYou don’t want to delay your application as this type of funding is limited. Apply now here\xa0for our web development program and note you are interested in using VET TEC.\n\xa0\nVET TEC IN-PERSON WORKSHOP AT OUR DALLAS CAMPUS on 1/12/22\nWe’re hosting a VET TECH workshop next Wednesday evening at our Dallas Campus to discuss everything about this new funding option for our Dallas Veterans.\nWe’re one of the few coding bootcamps in Dallas approved for the use of VET TEC funding, so this workshop will go over why Codeup is the best place to use your benefits and help launch your career in tech once you’re out of the military.\xa0\nDetails about the event and the link to grab your free tickets can be found here.\xa0\nThe VET TEC program details and eligibility requirements are listed below. You can also visit our VET TEC program page here.\n\xa0\nWhat is VET TEC?\nVET TEC, which stands for Veteran Employment Through Technology Education Courses, is a program through the VA that matches career accelerators like Codeup with veterans looking to gain high-tech skills. Programs like Codeup will help you build the skills you need to become, for example, a Web Developer, while the VA helps you to pay for the tuition.\n\xa0\nAre you eligible to use VET TEC funding?\nTo qualify for VET TEC, you must:\n1. Not be on active duty or are within 180 days of separating from active duty2. Qualify for VA Education Assistance under the GI Bill3. Have at least one day of unexpired GI Bill® entitlement\n\xa0\nWhen is VET TEC funding available?\nVET TEC renews its funding on an annual cycle in October.\xa0\nIMPORTANT:\xa0Funds run out very quickly each year. If you’re interested in using VET TEC, we recommend applying immediately and going through our admissions process as quickly as possible. That way, you’ll be accepted early and we can certify your enrollment as soon as VET TEC funding becomes available from the VA.\nDon’t delay your access to VET TEC funding and apply today!'

# %%
# Let's create a string that need clean up
original = """what are the math and stats principles you need for data science?oct 21, 2020 | data science


coming into our data science program, you will need to know some math and stats. however, many of our applicants actually learn in the application process  you dont need to be an expert before applying! data science is a very accessible field to anyone dedicated to learning new skills, and we can work with any applicant to help them learn what they need to know. but what skills do we mean, exactly? just what exactly are the data science math and stats principles you need to know?
what are the main math principles you need to know to get into codeups data science program?


algebra
do you know pemdas and can you solve for x? you will need to be or become comfortable with the following:

variables (x, y, n, etc.)
formulas, functions, and variable manipulations (e.g. x^2 = x + 6, solve for x).
order of evaluation: pemdas: parentheses, exponents, then multiplication, division, addition, and subtraction
commutativity where a + b = b + a
associativity where a + (b + c) = (a + b) + c
adding and subtracting matrices
a conceptual understanding of exponential growth/decay- things can increase at an increasing rate

descriptive statistics
know what a min, max, mode, median, and average are. have a conceptual understanding that stats/probability is about trying to quantify uncertainty.
data visualization
know what a scatterplot is and how to read a barplot.
how to learn and expand on these concepts
there are a number of great resources out there to teach you these and similar concepts. khan academy is a great starting place for data science math! if you want to know what exactly we assign our applicants, youll just have to apply!

what about once youre in codeup?


what you wont do
do we do any mathematical proofs for concepts or perform derivations? no. 
do we do any calculus and probability calculating by hand? no.
are we transforming equations, where we cancel out units or terms and do lots of algebraic gymnastics? no
what you will do
will we have python solve our linear algebra problems for us? yes
will we have python calculate probabilities, the area under a curve, and the slope of a line for us? yes
will we have python do all of the calculus for us? yes

see, the data science math and stats slice of the pie is certainly doable. if you like problem-solving and are ready to challenge yourself, youll love data science! if you are interested in learning about data science, just apply! our admissions manager can work with you to get you where you need to be starting from where you are now. let us help you get there so you can launch a great new career.

request more info





our programsfull stack web development
data science
cyber cloud
systems engineering





latest blog articles
codeup dallas open house
codeups placement team continues setting records
it certifications 101: why they matter, and why they dont
a rise in cyber attacks means opportunities for veterans in san antonio
use your gi bill benefits to land a job in tech























more from this category






codeup dallas open house
nov 30, 2021 | dallas newsletter, eventscome join us for the re-opening of our dallas campus with some drinks and snacks at codeup! curious about what our campus looks like? click here to register for free about this event come join us for the re-opening of our dallas campus with some drinks and snacks at...




codeups placement team continues setting records
nov 19, 2021 | codeup news, employersour placement team is simply defined as a group that manages relationships with our employer partners and our graduating students to help get our graduating students hired. last quarter the placement team helped 48 students get hired to life-changing careers in tech....




it certifications 101: why they matter, and why they dont
nov 18, 2021 | cybersecurity, it training, tips for prospective studentsaws, google, azure, red hat, comptia...these are big names in it! and not only for their products, but also for the certifications they offer. if youre new to tech, you might be wondering: do certifications really matter? welcome to it certifications 101! whats the...
"""

# %% [markdown]
# # 1
# Define a function named `basic_clean`. It should take in a string and apply some basic text cleaning to it:
# ```
# Lowercase everything
# Normalize unicode characters
# Replace anything that is not a letter, number, whitespace or a single quote.
# ```

# %%
def basic_clean(string):
    import unicodedata
    """
    Take in a string and apply some basic text cleaning:
    - Lowercase everything
    - Normalize unicode characters
    - Replace anything that is not a letter, number, whitespace or a single quote.
    """
    # lowercase the string
    string = string.lower()
    # return normal form for the unicode string, encode/remove ascii
    string = unicodedata.normalize('NFKD', string).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    string = re.sub(r"[^a-z0-9'\s]", '', string) #Replace anything that is not a letter, number, whitespace or a single quote
    return string

# %%
# make sure created basic_lean works 
basic_clean(string)
# Out:
# 'we are so happy to announce that vet tec benefits are now available to be used at our campus located in dallas tx our next dallas start date for our web development program is january 31st 2022\nyou dont want to delay your application as this type of funding is limited apply now here for our web development program and note you are interested in using vet tec\n \nvet tec inperson workshop at our dallas campus on 11222\nwere hosting a vet tech workshop next wednesday evening at our dallas campus to discuss everything about this new funding option for our dallas veterans\nwere one of the few coding bootcamps in dallas approved for the use of vet tec funding so this workshop will go over why codeup is the best place to use your benefits and help launch your career in tech once youre out of the military \ndetails about the event and the link to grab your free tickets can be found here \nthe vet tec program details and eligibility requirements are listed below you can also visit our vet tec program page here\n \nwhat is vet tec\nvet tec which stands for veteran employment through technology education courses is a program through the va that matches career accelerators like codeup with veterans looking to gain hightech skills programs like codeup will help you build the skills you need to become for example a web developer while the va helps you to pay for the tuition\n \nare you eligible to use vet tec funding\nto qualify for vet tec you must\n1 not be on active duty or are within 180 days of separating from active duty2 qualify for va education assistance under the gi bill3 have at least one day of unexpired gi bill entitlement\n \nwhen is vet tec funding available\nvet tec renews its funding on an annual cycle in october \nimportant funds run out very quickly each year if youre interested in using vet tec we recommend applying immediately and going through our admissions process as quickly as possible that way youll be accepted early and we can certify your enrollment as soon as vet tec funding becomes available from the va\ndont delay your access to vet tec funding and apply today'

# %%
basic_clean(original)
# Out:
# 'what are the math and stats principles you need for data scienceoct 21 2020  data science\n\n\ncoming into our data science program you will need to know some math and stats however many of our applicants actually learn in the application process  you dont need to be an expert before applying data science is a very accessible field to anyone dedicated to learning new skills and we can work with any applicant to help them learn what they need to know but what skills do we mean exactly just what exactly are the data science math and stats principles you need to know\nwhat are the main math principles you need to know to get into codeups data science program\n\n\nalgebra\ndo you know pemdas and can you solve for x you will need to be or become comfortable with the following\n\nvariables x y n etc\nformulas functions and variable manipulations eg x2  x  6 solve for x\norder of evaluation pemdas parentheses exponents then multiplication division addition and subtraction\ncommutativity where a  b  b  a\nassociativity where a  b  c  a  b  c\nadding and subtracting matrices\na conceptual understanding of exponential growthdecay things can increase at an increasing rate\n\ndescriptive statistics\nknow what a min max mode median and average are have a conceptual understanding that statsprobability is about trying to quantify uncertainty\ndata visualization\nknow what a scatterplot is and how to read a barplot\nhow to learn and expand on these concepts\nthere are a number of great resources out there to teach you these and similar concepts khan academy is a great starting place for data science math if you want to know what exactly we assign our applicants youll just have to apply\n\nwhat about once youre in codeup\n\n\nwhat you wont do\ndo we do any mathematical proofs for concepts or perform derivations no \ndo we do any calculus and probability calculating by hand no\nare we transforming equations where we cancel out units or terms and do lots of algebraic gymnastics no\nwhat you will do\nwill we have python solve our linear algebra problems for us yes\nwill we have python calculate probabilities the area under a curve and the slope of a line for us yes\nwill we have python do all of the calculus for us yes\n\nsee the data science math and stats slice of the pie is certainly doable if you like problemsolving and are ready to challenge yourself youll love data science if you are interested in learning about data science just apply our admissions manager can work with you to get you where you need to be starting from where you are now let us help you get there so you can launch a great new career\n\nrequest more info\n\n\n\n\n\nour programsfull stack web development\ndata science\ncyber cloud\nsystems engineering\n\n\n\n\n\nlatest blog articles\ncodeup dallas open house\ncodeups placement team continues setting records\nit certifications 101 why they matter and why they dont\na rise in cyber attacks means opportunities for veterans in san antonio\nuse your gi bill benefits to land a job in tech\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nmore from this category\n\n\n\n\n\n\ncodeup dallas open house\nnov 30 2021  dallas newsletter eventscome join us for the reopening of our dallas campus with some drinks and snacks at codeup curious about what our campus looks like click here to register for free about this event come join us for the reopening of our dallas campus with some drinks and snacks at\n\n\n\n\ncodeups placement team continues setting records\nnov 19 2021  codeup news employersour placement team is simply defined as a group that manages relationships with our employer partners and our graduating students to help get our graduating students hired last quarter the placement team helped 48 students get hired to lifechanging careers in tech\n\n\n\n\nit certifications 101 why they matter and why they dont\nnov 18 2021  cybersecurity it training tips for prospective studentsaws google azure red hat comptiathese are big names in it ...

# %% [markdown]
# # 2
# Define a function named `tokenize`. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(string):
    from nltk.tokenize.toktok import ToktokTokenizer
    '''
    This function takes in a string and tokenizes it
    '''
    # create the tokenizer
    tokenizer = nltk.tokenize.ToktokTokenizer()
    
    # use the tokenizer, return as a string
    string = tokenizer.tokenize(string, return_str = True)
    
    return string

# %%
tokenize(string)
# Out:
# 'We are so happy to announce that VET TEC benefits are now available to be used at our campus located in Dallas , TX ! Our next Dallas start date for our web development program is January 31st , 2022 ! \nYou don ’ t want to delay your application as this type of funding is limited. Apply now here for our web development program and note you are interested in using VET TEC.\n \nVET TEC IN-PERSON WORKSHOP AT OUR DALLAS CAMPUS on 1/12/22\nWe ’ re hosting a VET TECH workshop next Wednesday evening at our Dallas Campus to discuss everything about this new funding option for our Dallas Veterans.\nWe ’ re one of the few coding bootcamps in Dallas approved for the use of VET TEC funding , so this workshop will go over why Codeup is the best place to use your benefits and help launch your career in tech once you ’ re out of the military. \nDetails about the event and the link to grab your free tickets can be found here. \nThe VET TEC program details and eligibility requirements are listed below. You can also visit our VET TEC program page here.\n \nWhat is VET TEC ? \nVET TEC , which stands for Veteran Employment Through Technology Education Courses , is a program through the VA that matches career accelerators like Codeup with veterans looking to gain high-tech skills. Programs like Codeup will help you build the skills you need to become , for example , a Web Developer , while the VA helps you to pay for the tuition.\n \nAre you eligible to use VET TEC funding ? \nTo qualify for VET TEC , you must : \n1. Not be on active duty or are within 180 days of separating from active duty2. Qualify for VA Education Assistance under the GI Bill3. Have at least one day of unexpired GI Bill ® entitlement\n \nWhen is VET TEC funding available ? \nVET TEC renews its funding on an annual cycle in October. \nIMPORTANT : Funds run out very quickly each year. If you ’ re interested in using VET TEC , we recommend applying immediately and going through our admissions process as quickly as possible. That way , you ’ ll be accepted early and we can certify your enrollment as soon as VET TEC funding becomes available from the VA.\nDon ’ t delay your access to VET TEC funding and apply today !'

# %%
tokenize(original)
# Out:
# 'what are the math and stats principles you need for data science?oct 21 , 2020 &#124; data science\n\n\ncoming into our data science program , you will need to know some math and stats. however , many of our applicants actually learn in the application process you dont need to be an expert before applying ! data science is a very accessible field to anyone dedicated to learning new skills , and we can work with any applicant to help them learn what they need to know. but what skills do we mean , exactly ? just what exactly are the data science math and stats principles you need to know ? \nwhat are the main math principles you need to know to get into codeups data science program ? \n\n\nalgebra\ndo you know pemdas and can you solve for x ? you will need to be or become comfortable with the following : \n\nvariables ( x , y , n , etc. ) \nformulas , functions , and variable manipulations ( e.g. x^2 = x + 6 , solve for x ) .\norder of evaluation : pemdas : parentheses , exponents , then multiplication , division , addition , and subtraction\ncommutativity where a + b = b + a\nassociativity where a + ( b + c ) = ( a + b ) + c\nadding and subtracting matrices\na conceptual understanding of exponential growth/decay- things can increase at an increasing rate\n\ndescriptive statistics\nknow what a min , max , mode , median , and average are. have a conceptual understanding that stats/probability is about trying to quantify uncertainty.\ndata visualization\nknow what a scatterplot is and how to read a barplot.\nhow to learn and expand on these concepts\nthere are a number of great resources out there to teach you these and similar concepts. khan academy is a great starting place for data science math ! if you want to know what exactly we assign our applicants , youll just have to apply ! \n\nwhat about once youre in codeup ? \n\n\nwhat you wont do\ndo we do any mathematical proofs for concepts or perform derivations ? no. \ndo we do any calculus and probability calculating by hand ? no.\nare we transforming equations , where we cancel out units or terms and do lots of algebraic gymnastics ? no\nwhat you will do\nwill we have python solve our linear algebra problems for us ? yes\nwill we have python calculate probabilities , the area under a curve , and the slope of a line for us ? yes\nwill we have python do all of the calculus for us ? yes\n\nsee , the data science math and stats slice of the pie is certainly doable. if you like problem-solving and are ready to challenge yourself , youll love data science ! if you are interested in learning about data science , just apply ! our admissions manager can work with you to get you where you need to be starting from where you are now. let us help you get there so you can launch a great new career.\n\nrequest more info\n\n\n\n\n\nour programsfull stack web development\ndata science\ncyber cloud\nsystems engineering\n\n\n\n\n\nlatest blog articles\ncodeup dallas open house\ncodeups placement team continues setting records\nit certifications 101 : why they matter , and why they dont\na rise in cyber attacks means opportunities for veterans in san antonio\nuse your gi bill benefits to land a job in tech\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nmore from this category\n\n\n\n\n\n\ncodeup dallas open house\nnov 30 , 2021 &#124; dallas newsletter , eventscome join us for the re-opening of our dallas campus with some drinks and snacks at codeup ! curious about what our campus looks like ? click here to register for free about this event come join us for the re-opening of our dallas campus with some drinks and snacks at ... \n\n\n\n\ncodeups placement team continues setting records\nnov 19 , 2021 &#124; codeup news , employersour placement team is simply defined as a group that manages relationships with our employer partners and our graduating students to help get our graduating students hired. last quarter the placement team helped 48 students get hired to life-changing careers in tech ... ...

# %% [markdown]
# # 3
# Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(string):
    '''
    This function takes in a string and
    returns a string with stemmed words.
    '''
    # Create porter stemmer
    ps = nltk.porter.PorterStemmer()
    
    # Use 'stemmer' to stem each word in the list of words we created by using '.split'
    stems = [ps.stem(word) for word in string.split()]
    
    # Join our lists of words into a string again and assign to a variable
    string = ' '.join(stems)
    
    return string

# %%
stem(string)
# Out:
# 'we are so happi to announc that vet tec benefit are now avail to be use at our campu locat in dallas, tx! our next dalla start date for our web develop program is januari 31st, 2022! you don’t want to delay your applic as thi type of fund is limited. appli now here for our web develop program and note you are interest in use vet tec. vet tec in-person workshop at our dalla campu on 1/12/22 we’r host a vet tech workshop next wednesday even at our dalla campu to discuss everyth about thi new fund option for our dalla veterans. we’r one of the few code bootcamp in dalla approv for the use of vet tec funding, so thi workshop will go over whi codeup is the best place to use your benefit and help launch your career in tech onc you’r out of the military. detail about the event and the link to grab your free ticket can be found here. the vet tec program detail and elig requir are list below. you can also visit our vet tec program page here. what is vet tec? vet tec, which stand for veteran employ through technolog educ courses, is a program through the va that match career acceler like codeup with veteran look to gain high-tech skills. program like codeup will help you build the skill you need to become, for example, a web developer, while the va help you to pay for the tuition. are you elig to use vet tec funding? to qualifi for vet tec, you must: 1. not be on activ duti or are within 180 day of separ from activ duty2. qualifi for va educ assist under the gi bill3. have at least one day of unexpir gi bill® entitl when is vet tec fund available? vet tec renew it fund on an annual cycl in october. important: fund run out veri quickli each year. if you’r interest in use vet tec, we recommend appli immedi and go through our admiss process as quickli as possible. that way, you’ll be accept earli and we can certifi your enrol as soon as vet tec fund becom avail from the va. don’t delay your access to vet tec fund and appli today!'

# %%
stem(original)
# Out:
# 'what are the math and stat principl you need for data science?oct 21, 2020 | data scienc come into our data scienc program, you will need to know some math and stats. however, mani of our applic actual learn in the applic process you dont need to be an expert befor applying! data scienc is a veri access field to anyon dedic to learn new skills, and we can work with ani applic to help them learn what they need to know. but what skill do we mean, exactly? just what exactli are the data scienc math and stat principl you need to know? what are the main math principl you need to know to get into codeup data scienc program? algebra do you know pemda and can you solv for x? you will need to be or becom comfort with the following: variabl (x, y, n, etc.) formulas, functions, and variabl manipul (e.g. x^2 = x + 6, solv for x). order of evaluation: pemdas: parentheses, exponents, then multiplication, division, addition, and subtract commut where a + b = b + a associ where a + (b + c) = (a + b) + c ad and subtract matric a conceptu understand of exponenti growth/decay- thing can increas at an increas rate descript statist know what a min, max, mode, median, and averag are. have a conceptu understand that stats/prob is about tri to quantifi uncertainty. data visual know what a scatterplot is and how to read a barplot. how to learn and expand on these concept there are a number of great resourc out there to teach you these and similar concepts. khan academi is a great start place for data scienc math! if you want to know what exactli we assign our applicants, youll just have to apply! what about onc your in codeup? what you wont do do we do ani mathemat proof for concept or perform derivations? no. do we do ani calculu and probabl calcul by hand? no. are we transform equations, where we cancel out unit or term and do lot of algebra gymnastics? no what you will do will we have python solv our linear algebra problem for us? ye will we have python calcul probabilities, the area under a curve, and the slope of a line for us? ye will we have python do all of the calculu for us? ye see, the data scienc math and stat slice of the pie is certainli doable. if you like problem-solv and are readi to challeng yourself, youll love data science! if you are interest in learn about data science, just apply! our admiss manag can work with you to get you where you need to be start from where you are now. let us help you get there so you can launch a great new career. request more info our programsful stack web develop data scienc cyber cloud system engin latest blog articl codeup dalla open hous codeup placement team continu set record it certif 101: whi they matter, and whi they dont a rise in cyber attack mean opportun for veteran in san antonio use your gi bill benefit to land a job in tech more from thi categori codeup dalla open hous nov 30, 2021 | dalla newsletter, eventscom join us for the re-open of our dalla campu with some drink and snack at codeup! curiou about what our campu look like? click here to regist for free about thi event come join us for the re-open of our dalla campu with some drink and snack at... codeup placement team continu set record nov 19, 2021 | codeup news, employersour placement team is simpli defin as a group that manag relationship with our employ partner and our graduat student to help get our graduat student hired. last quarter the placement team help 48 student get hire to life-chang career in tech.... it certif 101: whi they matter, and whi they dont nov 18, 2021 | cybersecurity, it training, tip for prospect studentsaws, google, azure, red hat, comptia...thes are big name in it! and not onli for their products, but also for the certif they offer. if your new to tech, you might be wondering: do certif realli matter? welcom to it certif 101! what the...'

# %% [markdown]
# # 4

# %%
def lemmatize(string):
    '''
    This function takes in a string and
    returns a string with lammatized words.
    
    Word **stems** are the base form of a word
    '''
    # Create the lemmatizer.
    wnl = nltk.stem.WordNetLemmatizer()
    
    # Use the lemmatizer on each word in the list of words we created by using split.
    lemmas = [wnl.lemmatize(word) for word in string.split()]
    
    # Join our list of words into a string again and assign to a variable.
    string = ' '.join(lemmas)
    
    return string

# %%
lemmatize(string)
# Out:
# 'We are so happy to announce that VET TEC benefit are now available to be used at our campus located in Dallas, TX! Our next Dallas start date for our web development program is January 31st, 2022! You don’t want to delay your application a this type of funding is limited. Apply now here for our web development program and note you are interested in using VET TEC. VET TEC IN-PERSON WORKSHOP AT OUR DALLAS CAMPUS on 1/12/22 We’re hosting a VET TECH workshop next Wednesday evening at our Dallas Campus to discus everything about this new funding option for our Dallas Veterans. We’re one of the few coding bootcamps in Dallas approved for the use of VET TEC funding, so this workshop will go over why Codeup is the best place to use your benefit and help launch your career in tech once you’re out of the military. Details about the event and the link to grab your free ticket can be found here. The VET TEC program detail and eligibility requirement are listed below. You can also visit our VET TEC program page here. What is VET TEC? VET TEC, which stand for Veteran Employment Through Technology Education Courses, is a program through the VA that match career accelerator like Codeup with veteran looking to gain high-tech skills. Programs like Codeup will help you build the skill you need to become, for example, a Web Developer, while the VA help you to pay for the tuition. Are you eligible to use VET TEC funding? To qualify for VET TEC, you must: 1. Not be on active duty or are within 180 day of separating from active duty2. Qualify for VA Education Assistance under the GI Bill3. Have at least one day of unexpired GI Bill® entitlement When is VET TEC funding available? VET TEC renews it funding on an annual cycle in October. IMPORTANT: Funds run out very quickly each year. If you’re interested in using VET TEC, we recommend applying immediately and going through our admission process a quickly a possible. That way, you’ll be accepted early and we can certify your enrollment a soon a VET TEC funding becomes available from the VA. Don’t delay your access to VET TEC funding and apply today!'

# %% [markdown]
# # 5
# Define a function named `remove_stopwords`. It should accept some text and return the text after removing all the stopwords.

# %%
def remove_stopwords(string, extra_words = [], exclude_words = []):
    '''
    This function takes in a string, optional extra_words and exclude_words parameters
    with default empty lists and returns a string.
    '''
    # Create stopword_list
    stopword_list = stopwords.words('english')
    
    # Remove 'exclude_words' from stopword_list to keep these in text
    stopword_list = set(stopword_list) - set(exclude_words)
    
    # Join 'extra_words' with 'stopword_list'
    stopword_list = stopword_list.union(set(extra_words))

    # Split words in string
    words = string.split()
    
    # Create a list of words from 'string' with stopwords removed and assigned to variable
    filtered_words = [word for word in words if word not in stopword_list]
    
    # Join words in list back into strings and assign to a variable
    string_without_stopwords = ' '.join(filtered_words)
    
    # print count of removed stop worlds 
    print('Removed {} stopwords'.format(len(words) - len(filtered_words)))
    print('---')
    
    return string_without_stopwords

# %%
remove_stopwords(string)
# Out:
# Removed 137 stopwords
# ---
# 'We happy announce VET TEC benefits available used campus located Dallas, TX! Our next Dallas start date web development program January 31st, 2022! You don’t want delay application type funding limited. Apply web development program note interested using VET TEC. VET TEC IN-PERSON WORKSHOP AT OUR DALLAS CAMPUS 1/12/22 We’re hosting VET TECH workshop next Wednesday evening Dallas Campus discuss everything new funding option Dallas Veterans. We’re one coding bootcamps Dallas approved use VET TEC funding, workshop go Codeup best place use benefits help launch career tech you’re military. Details event link grab free tickets found here. The VET TEC program details eligibility requirements listed below. You also visit VET TEC program page here. What VET TEC? VET TEC, stands Veteran Employment Through Technology Education Courses, program VA matches career accelerators like Codeup veterans looking gain high-tech skills. Programs like Codeup help build skills need become, example, Web Developer, VA helps pay tuition. Are eligible use VET TEC funding? To qualify VET TEC, must: 1. Not active duty within 180 days separating active duty2. Qualify VA Education Assistance GI Bill3. Have least one day unexpired GI Bill® entitlement When VET TEC funding available? VET TEC renews funding annual cycle October. IMPORTANT: Funds run quickly year. If you’re interested using VET TEC, recommend applying immediately going admissions process quickly possible. That way, you’ll accepted early certify enrollment soon VET TEC funding becomes available VA. Don’t delay access VET TEC funding apply today!'

# %% [markdown]
# # 6
# Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe `news_df`

# %%
# acquire news data and name it `news_df`
news_df = acquire.get_inshorts_articles()
news_df
# Out:
#                                                 title           author  \
# 0   I used to catch Patna-Banaras train to listen ...   Pragya Swastik
# 1   Lata Mangeshkar will eternally cast her shadow...     Kiran Khatri
# 2   Nostalgia with moist eyes & lump in throat: Ko...     Kiran Khatri
# 3   There's no greater tribute to our unity than L...      Hiral Goyal
# 4   COVID, you did your worst & stole our voice: M...  Sakshita Khosla
# ..                                                ...              ...
# 95  Lata ji's 'Ae mere watan ke logo' song leaves ...       Disha Jana
# 96  Spent her last 10 days with her, left nothing ...       Ria Kapoor
# 97  '3 Idiots' poster features in Thai show 'Somet...    Kriti Kambiri
# 98  Shweta shares brother Abhishek's pic with mom ...       Udit Gupta
# 99  Awkwafina apologises amid 'Blaccent' controver...    Kriti Kambiri
#
#                                               content                date  \
# 0   Vedanta's billionaire Chairman Anil Agarwal in...  06 Feb 2022,Sunday
# 1   Biocon's Executive Chairperson Kiran Mazumdar-...  06 Feb 2022,Sunday
# 2   Kotak Mahindra Bank MD Uday Kotak took to Twit...  06 Feb 2022,Sunday
# 3   Adani Group's Chairman Gautam Adani took to Tw...  06 Feb 2022,Sunday
# 4   Businessman Anand Mahindra on Sunday shared a ...  06 Feb 2022,Sunday
# ..                                                ...                 ...
# 95  Defence Minister Rajnath Singh paid tribute to...  06 Feb 2022,Sunday
# 96  Actor Andrew Garfield said he got to spend tim...  06 Feb 2022,Sunday
# 97  A poster of Aamir Khan-starrer 2009 film '3 Id...  06 Feb 2022,Sunday
# 98  Shweta Bachchan on Saturday wished her brother...  06 Feb 2022,Sunday
# 99  Rapper-actress Awkwafina has apologised amid t...  06 Feb 2022,Sunday
#
#          category
# 0        business
# 1        business
# 2        business
# 3        business
# 4        business
# ..            ...
# 95  entertainment
# 96  entertainment
# 97  entertainment
# 98  entertainment
# 99  entertainment
#
# [100 rows x 5 columns]

# %% [markdown]
# # 7
# Make another dataframe for the Codeup blog posts. Name the dataframe `codeup_df`

# %%
codeup_df = acquire.title_contetn_date_df()
codeup_df
# Out:
#                                                title  \
# 0  VET TEC Funding Now Available For Dallas Veter...
# 1         Codeup Start Dates for March 2022 - Codeup
# 2  Dallas Campus Re-opens With New Grant Partner ...
# 3  Codeup Helps 40 Grads Land Tech Jobs in Just 1...
# 4  Is Codeup the Best Bootcamp in San Antonio...o...
#
#                                              content published_date
# 0  We are so happy to announce that VET TEC benef...    Jan 7, 2022
# 1  As we approach the end of January we wanted to...   Jan 26, 2022
# 2  We are happy to announce that our Dallas campu...   Dec 30, 2021
# 3  Our Placement Team is simply defined as a grou...   Nov 19, 2021
# 4  Looking for the best data science bootcamp in ...   Sep 16, 2021

# %% [markdown]
# # 8
# For each dataframe, produce the following columns:
#
# - `title` to hold the title
# - `original` to hold the original article/post content
# - `clean` to hold the normalized and tokenized original with the stopwords removed.
# - `stemmed` to hold the stemmed version of the cleaned data.
# - `lemmatized` to hold the lemmatized version of the cleaned data.

# %%
# Rename 'content' to 'original' column for news articles
news_df = news_df.rename(columns = {'content': 'original'})
# Rename 'content' to 'original' column for codeup blogs
codeup_df = codeup_df.rename(columns = {'content': 'original'})

# %%
news_df.head(2)
# Out:
#                                                title          author  \
# 0  I used to catch Patna-Banaras train to listen ...  Pragya Swastik
# 1  Lata Mangeshkar will eternally cast her shadow...    Kiran Khatri
#
#                                             original                date  \
# 0  Vedanta's billionaire Chairman Anil Agarwal in...  06 Feb 2022,Sunday
# 1  Biocon's Executive Chairperson Kiran Mazumdar-...  06 Feb 2022,Sunday
#
#    category
# 0  business
# 1  business

# %%
# create a functionnthat would add clean, stemmed, and lammatized columns to the df
def prep_articles_add_to_df(df, extra_words = [], exclude_words = []):
    
    '''
    This function takes in a dataframe, a list of extra words to supplement
    the list of stop words, and a list of words to exclude from the stop words list
    The function returns a dataframe 
    supplemented with clean, stemmed, and lemmatized columns
    '''
    # produce 'original' column
    df = df.rename(columns = {'content': 'original'})
    
    # produce 'clean' column. clean and then tokenize
    df['clean'] = df['original'].apply(basic_clean)\
    .apply(tokenize)\
    .apply(remove_stopwords, extra_words = extra_words, exclude_words = exclude_words)
          
    # produce 'stemmed' column from cleaned column
    df['stemmed'] = df.clean.apply(stem)
    
    # produce 'lemmatizemed' column from cleaned column
    df['lemmatized'] = df.clean.apply(lemmatize)
    
    return df

# %%
news_df = prep_articles_add_to_df(news_df)
# Out:
# Removed 26 stopwords
# ---
# Removed 24 stopwords
# ---
# Removed 19 stopwords
# ---
# Removed 23 stopwords
# ---
# Removed 22 stopwords
# ---
# Removed 25 stopwords
# ---
# Removed 28 stopwords
# ---
# Removed 18 stopwords
# ---
# Removed 21 stopwords
# ---
# Removed 23 stopwords
# ---
# Removed 25 stopwords
# ---
# Removed 28 stopwords
# ---
# Removed 18 stopwords
# ---
# Removed 21 stopwords
# ---
# Removed 18 stopwords
# ---
# Removed 22 stopwords
# ---
# Removed 26 stopwords
# ---
# Removed 24 stopwords
# ---
# Removed 19 stopwords
# ---
# Removed 27 stopwords
# ---
# Removed 16 stopwords
# ---
# Removed 28 stopwords
# ---
# Removed 22 stopwords
# ---
# Removed 24 stopwords
# ---
# Removed 24 stopwords
# ---
# Removed 17 stopwords
# ---
# Removed 19 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 28 stopwords
# ---
# Removed 26 stopwords
# ---
# Removed 21 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 19 stopwords
# ---
# Removed 14 stopwords
# ---
# Removed 22 stopwords
# ---
# Removed 21 stopwords
# ---
# Removed 25 stopwords
# ---
# Removed 24 stopwords
# ---
# Removed 17 stopwords
# ---
# Removed 22 stopwords
# ---
# Removed 29 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 17 stopwords
# ---
# Removed 25 stopwords
# ---
# Removed 22 stopwords
# ---
# Removed 18 stopwords
# ---
# Removed 17 stopwords
# ---
# Removed 21 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 19 stopwords
# ---
# Removed 23 stopwords
# ---
# Removed 26 stopwords
# ---
# Removed 23 stopwords
# ---
# Removed 21 stopwords
# ---
# Removed 22 stopwords
# ---
# Removed 23 stopwords
# ---
# Removed 24 stopwords
# ---
# Removed 23 stopwords
# ---
# Removed 18 stopwords
# ---
# Removed 18 stopwords
# ---
# Removed 26 stopwords
# ---
# Removed 23 stopwords
# ---
# Removed 22 stopwords
# ---
# Removed 31 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 26 stopwords
# ---
# Removed 19 stopwords
# ---
# Removed 29 stopwords
# ---
# Removed 24 stopwords
# ---
# Removed 29 stopwords
# ---
# Removed 28 stopwords
# ---
# Removed 27 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 25 stopwords
# ---
# Removed 17 stopwords
# ---
# Removed 15 stopwords
# ---
# Removed 22 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 24 stopwords
# ---
# Removed 27 stopwords
# ---
# Removed 25 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 16 stopwords
# ---
# Removed 25 stopwords
# ---
# Removed 18 stopwords
# ---
# Removed 28 stopwords
# ---
# Removed 26 stopwords
# ---
# Removed 37 stopwords
# ---
# Removed 22 stopwords
# ---
# Removed 29 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 17 stopwords
# ---
# Removed 23 stopwords
# ---
# Removed 16 stopwords
# ---
# Removed 20 stopwords
# ---
# Removed 26 stopwords
# ---
# Removed 25 stopwords
# ---
# Removed 23 stopwords
# ---
# Removed 27 stopwords
# ---

# %%
news_df.head()
# Out:
#                                                title           author  \
# 0  I used to catch Patna-Banaras train to listen ...   Pragya Swastik
# 1  Lata Mangeshkar will eternally cast her shadow...     Kiran Khatri
# 2  Nostalgia with moist eyes & lump in throat: Ko...     Kiran Khatri
# 3  There's no greater tribute to our unity than L...      Hiral Goyal
# 4  COVID, you did your worst & stole our voice: M...  Sakshita Khosla
#
#                                             original                date  \
# 0  Vedanta's billionaire Chairman Anil Agarwal in...  06 Feb 2022,Sunday
# 1  Biocon's Executive Chairperson Kiran Mazumdar-...  06 Feb 2022,Sunday
# 2  Kotak Mahindra Bank MD Uday Kotak took to Twit...  06 Feb 2022,Sunday
# 3  Adani Group's Chairman Gautam Adani took to Tw...  06 Feb 2022,Sunday
# 4  Businessman Anand Mahindra on Sunday shared a ...  06 Feb 2022,Sunday
#
#    category                                              clean  \
# 0  business  vedanta ' billionaire chairman anil agarwal tw...
# 1  business  biocon ' executive chairperson kiran mazumdars...
# 2  business  kotak mahindra bank md uday kotak took twitter...
# 3  business  adani group ' chairman gautam adani took twitt...
# 4  business  businessman anand mahindra sunday shared pictu...
#
#                                              stemmed  \
# 0  vedanta ' billionair chairman anil agarw tweet...
# 1  biocon ' execut chairperson kiran mazumdarshaw...
# 2  kotak mahindra bank md uday kotak took twitter...
# 3  adani group ' chairman gautam adani took twitt...
# 4  businessman anand mahindra sunday share pictur...
#
#                                           lemmatized
# 0  vedanta ' billionaire chairman anil agarwal tw...
# 1  biocon ' executive chairperson kiran mazumdars...
# 2  kotak mahindra bank md uday kotak took twitter...
# 3  adani group ' chairman gautam adani took twitt...
# 4  businessman anand mahindra sunday shared pictu...

# %%
codeup_df = prep_articles_add_to_df(codeup_df)
# Out:
# Removed 158 stopwords
# ---
# Removed 128 stopwords
# ---
# Removed 95 stopwords
# ---
# Removed 108 stopwords
# ---
# Removed 184 stopwords
# ---

# %%
codeup_df.head()
# Out:
#                                                title  \
# 0  VET TEC Funding Now Available For Dallas Veter...
# 1         Codeup Start Dates for March 2022 - Codeup
# 2  Dallas Campus Re-opens With New Grant Partner ...
# 3  Codeup Helps 40 Grads Land Tech Jobs in Just 1...
# 4  Is Codeup the Best Bootcamp in San Antonio...o...
#
#                                             original published_date  \
# 0  We are so happy to announce that VET TEC benef...    Jan 7, 2022
# 1  As we approach the end of January we wanted to...   Jan 26, 2022
# 2  We are happy to announce that our Dallas campu...   Dec 30, 2021
# 3  Our Placement Team is simply defined as a grou...   Nov 19, 2021
# 4  Looking for the best data science bootcamp in ...   Sep 16, 2021
#
#                                                clean  \
# 0  happy announce vet tec benefits available used...
# 1  approach end january wanted look forward next ...
# 2  happy announce dallas campus reopened better y...
# 3  placement team simply defined group manages re...
# 4  looking best data science bootcamp world best ...
#
#                                              stemmed  \
# 0  happi announc vet tec benefit avail use campu ...
# 1  approach end januari want look forward next st...
# 2  happi announc dalla campu reopen better yet ne...
# 3  placement team simpli defin group manag relati...
# 4  look best data scienc bootcamp world best code...
#
#                                           lemmatized
# 0  happy announce vet tec benefit available used ...
# 1  approach end january wanted look forward next ...
# 2  happy announce dallas campus reopened better y...
# 3  placement team simply defined group manages re...
# 4  looking best data science bootcamp world best ...
